# %% [markdown]
# **1. Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top
# 5 and bottom 5 records**

# %%
import pandas as pd   #importing required libraries
import numpy as np

# %%
# Reading the provided dataset using pandas library

df = pd.read_csv('youtube_dislike_dataset.csv') #using read_csv from pandas
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %%
# Retrieving top 5 records

df.head() #head() returns top 5 records
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
# Retrieving bottom 5 records

df.tail() #tail() returns bottom 5 records
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %% [markdown]
# **2.Check the info of the dataframe and write your inferences on data types and shape of the dataset**

# %%
# checking info of  the dataset using info()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %% [markdown]
# **Inferences**
#
# 1.video_id,title,channel_id,channel_title,published_at,tags,descriptions,comments - all these features are of object datatype
#    hence performing numeric operations are not possible unless if we can convert it into float or int datatype
#
# 2.View_count,likes,dislikes,comment_count - all these features are int64 datatype,hence numeric operations are possible and
#    the analysis will majorly depend on these features

# %%
#shape of  the dataset 

df.shape #it contains 37422 rows and 12 columns 
#the 12 column represents that this data has 12 different features 
# 37422 number of rows are there in this dataset
# Out:
# (37422, 12)

# %% [markdown]
# **3.Check for the Percentage of the missing values and drop or impute them.**

# %%
#isnull() returns the boolean of all null values 
# sum() to add the null values for each features 

df.isnull().sum()  #comments has 158 null values
# Out:
# video_id           0
# title              0
# channel_id         0
# channel_title      0
# published_at       0
# view_count         0
# likes              0
# dislikes           0
# comment_count      0
# tags               0
# description        0
# comments         158
# dtype: int64

# %%
#dividing the isnull().sum() by len of dataframe and multiplying by 100 gives the exact percentage of null values in each column
# round function is used to round it to 2 decimal places

np.round(df.isnull().sum()/len(df)*100,2)   #comments columns has 0.42 percent null values
# Out:
# video_id         0.00
# title            0.00
# channel_id       0.00
# channel_title    0.00
# published_at     0.00
# view_count       0.00
# likes            0.00
# dislikes         0.00
# comment_count    0.00
# tags             0.00
# description      0.00
# comments         0.42
# dtype: float64

# %%
df.dropna(axis=0,inplace=True) #dropping the null values using dropna
                               # using axis = 0 for droping the  null value rows and inplace = true for permanently dropping it

# %%
df.isnull().sum()  # checking if null value exist or not
# Out:
# video_id         0
# title            0
# channel_id       0
# channel_title    0
# published_at     0
# view_count       0
# likes            0
# dislikes         0
# comment_count    0
# tags             0
# description      0
# comments         0
# dtype: int64

# %%
df.shape  # After removing all the rows with null values, the rows reduced to 37264 from 37422
# Out:
# (37264, 12)

# %%
df['comments'].describe() #here we can see all the comments are unique , hence replacing null with mode is not possible .
# Out:
# count                                                 37264
# unique                                                37264
# top       Respect to Dortmund fans,must be sad losing hi...
# freq                                                      1
# Name: comments, dtype: object

# %% [markdown]
# **4. Check the statistical summary of both numerical and categorical columns and write your inferences.**

# %%
df.describe()  # describe() is used to get statistical summary of  numeric columns
# Out:
#          view_count         likes      dislikes  comment_count
# count  3.726400e+04  3.726400e+04  3.726400e+04   3.726400e+04
# mean   5.710821e+06  1.672867e+05  4.996434e+03   9.966953e+03
# std    2.431304e+07  5.384931e+05  3.075194e+04   1.173465e+05
# min    2.036800e+04  2.200000e+01  3.000000e+00   1.000000e+00
# 25%    5.141305e+05  1.331725e+04  2.827500e+02   9.140000e+02
# 50%    1.321860e+06  4.255600e+04  7.980000e+02   2.347000e+03
# 75%    3.674527e+06  1.309665e+05  2.466250e+03   6.212000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07

# %% [markdown]
# 1. the total count of all the features individually are 37264 after removing null values
# 2. The average  view counts is 5,710,821 , which states that on an average the number of views is over 5 million for a video
# 3. the least watched video has a  view count of 20,368
# 4. the maximum views of a video is found out to be 1,322,796,924
# 5. The avg number of likes  for a  video is found out to be 1,672,867
# 6. The minimum number of likes for a video is 22
# 7. The maximum number of likes  for a video is 31,837,675
# 8. The average number of dislikes for a video is turned out to be 4996
# 9. The min number of dislikes for a video is 3
# 10. The maximum number of dislikes a video got is found to be 2,397,733
# 11. The average number of comments for a video is 9,967 almost (10,000)
# 12. The minimum number of comments for a particular video is 1
# 13. The maximum number of comments for a video is 16,071,030

# %% [markdown]
# **Statistical summary of categorical columns**
#
# Retrieving the statistical summary of categorical columns are not possible , because all the values in the categorical columns are unique , hence dummy encoding isn't possible to proceed  further for analysis

# %% [markdown]
# **5.Convert datatype of column published_at from object to pandas datetime.**

# %%
df = pd.DataFrame(df)

# %%
# .dtypes to check datatype
df['published_at'].dtypes # original datatype is object
# Out:
# dtype('O')

# %%
df['published_at'] = df['published_at'].astype('datetime64')
#converting column 'published_at' into datetime datatype using astype()

df.dtypes
# Out:
# video_id                 object
# title                    object
# channel_id               object
# channel_title            object
# published_at     datetime64[ns]
# view_count                int64
# likes                     int64
# dislikes                  int64
# comment_count             int64
# tags                     object
# description              object
# comments                 object
# dtype: object

# %% [markdown]
# **6.Create a new column as 'published_month' using the column published_at (display the months only)**

# %%
#creating a new column 'published_month'
df['published_month'] = pd.DatetimeIndex(df['published_at']).month  
# using pandas DatetimeIndex().month to extract the month from the column

# %%
df[['published_month','published_at']].head() # check
# Out:
#    published_month        published_at
# 0                7 2021-07-01 10:00:00
# 1                6 2021-06-10 16:00:00
# 2                9 2021-09-20 01:03:32
# 3                3 2021-03-03 10:00:17
# 4               12 2021-12-07 13:00:00

# %% [markdown]
# **7. Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb'
# and so on.....**

# %%
#creating a dictionary with month numbers as keys and month names as values
month_names= pd.Series({1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'June',7:'July',8:'Aug',9:'Sep',10:'Oct',11:'Nov',12:'Dec'})

# %%
pd.DataFrame(month_names)
# Out:
#        0
# 1    Jan
# 2    Feb
# 3    Mar
# 4    Apr
# 5    May
# 6   June
# 7   July
# 8    Aug
# 9    Sep
# 10   Oct
# 11   Nov
# 12   Dec

# %%
#assigning the month names to their respective month numbers

df['published_month'] = df['published_month'].apply(lambda m:month_names[m])
# using lambda function we're assigning the name of months to their respective numbers

# %%
df[['published_month']] # the month numbers are converted to month names
# Out:
#       published_month
# 0                July
# 1                June
# 2                 Sep
# 3                 Mar
# 4                 Dec
# ...               ...
# 37417             Feb
# 37418             Jan
# 37419            June
# 37420             Oct
# 37421             May
#
# [37264 rows x 1 columns]

# %% [markdown]
# **8. Find the number of videos published each month and arrange the months in a decreasing order based
# on the video count.**

# %%
# using Groupby to group the data by column names
# passing  titles as values for groupby function and count as aggregation
# ascending as false gives the data on descending order of their counts

title_nums = df.groupby(by='published_month')['title'].count().sort_values(ascending=False).to_frame()

# %%
title_nums
# Out:
#                  title
# published_month
# Oct               4976
# Sep               4854
# Nov               4821
# Aug               4250
# Dec               3063
# July              2331
# June              2305
# Mar               2248
# Feb               2125
# Apr               2119
# Jan               2099
# May               2073

# %%
#here video_id is  used as a value for groupby function and their counts are retrieved
#A check to make sure that both features gives the same answer.

video_nums = df.groupby('published_month')['video_id'].count().sort_values(ascending=False).to_frame()
video_nums
# Out:
#                  video_id
# published_month
# Oct                  4976
# Sep                  4854
# Nov                  4821
# Aug                  4250
# Dec                  3063
# July                 2331
# June                 2305
# Mar                  2248
# Feb                  2125
# Apr                  2119
# Jan                  2099
# May                  2073

# %% [markdown]
# **9. Find the count of unique video_id, channel_id and channel_title.**

# %%
#  nunique() to find count of unique elements

# %%
#count of unique video_id
df['video_id'].nunique() #all the values are unique
# Out:
# 37264

# %%
#count of unique channel_id
df['channel_id'].nunique() #10891 unique channel id's out of 37264
# Out:
# 10891

# %%
#count of channel title
df['channel_title'].nunique() #10813 unique channel titles
# Out:
# 10813

# %%
#count summary
df[['video_id','channel_id','channel_title']].describe()
# Out:
#            video_id                channel_id        channel_title
# count         37264                     37264                37264
# unique        37264                     10891                10813
# top     --0bCF-iK2E  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1                       533                  533

# %% [markdown]
# **10. Find the top10 channel names having the highest number of videos in the dataset and the bottom10
# having lowest number of videos.**

# %%
# groupby () to group under channel name 
# count of video title as value to groupby function .to group the counts of videos to their respective channel names
# ascending = false to arrange in descending order to extract top and  bottom 10 values

top = df.groupby('channel_title')['title'].count().sort_values(ascending=False).to_frame()

top.head(10) # top 10 channel names by  their video counts
# Out:
#                      title
# channel_title
# Sky Sports Football    533
# The United Stand       301
# BT Sport               246
# NBA                    209
# NFL                    162
# WWE                    122
# SSSniperWolf            99
# SSundee                 98
# FORMULA 1               87
# NHL                     86

# %%
top.tail(10) #bottom 10 channel names by their video counts
# Out:
#                  title
# channel_title
# Karikku Tuned        1
# Karen Bustillos      1
# Karen Aslanyan       1
# Karchez              1
# Karate Combat        1
# Kaptain Kuba         1
# Kanye West           1
# Kannur kitchen       1
# Kannada Cinema       1
# zoom                 1

# %% [markdown]
# **11. Find the title of the video which has the maximum number of likes and the title of the video having
# minimum likes and write your inferences.**

# %%
index = df['likes'].sort_values(ascending=False).to_frame()
index # sorting the data in terms of number of likes  in descending order to get the top most and the least liked video
# Out:
#           likes
# 26143  31837675
# 19583  20649409
# 34758  17864527
# 57     16354127
# 8176   15449003
# ...         ...
# 29743       106
# 30462        97
# 15597        29
# 29482        28
# 23855        22
#
# [37264 rows x 1 columns]

# %%
index.head(1) # getting the exact number of likes for top most liked video
# Out:
#           likes
# 26143  31837675

# %%
name1 = df[df['likes']==31837675] #getting all features about the top most liked video by  passing likes number to locate the data
name1

#INFERENCES:

#1.The name of the most liked video is ""BTS () 'Dynamite' Official MV"" which has a total of ""31837675"" likes
#2.The total number of views for this video is 1322796924 , Since the number of views is very high , we can say it as one
#  of the  main  reasons for the most number of likes
# Out:
#           video_id                          title                channel_id  \
# 26143  gdZLi9oWNZg  BTS () 'Dynamite' Official MV  UC3IZKseVpdzPSBaWxBxundA
#
#       channel_title        published_at  view_count     likes  dislikes  \
# 26143   HYBE LABELS 2020-08-21 03:58:10  1322796924  31837675   1814333
#
#        comment_count                   tags  \
# 26143       16071029  BIGHIT   BTS BANGTAN
#
#                                              description  \
# 26143  BTS () 'Dynamite' Official MV\n\n\nCredits:\nD...
#
#                                                 comments published_month
# 26143  Armys, we will strive for the mv to reach 100 ...             Aug

# %%
name1[['title','likes']]  # Extracting only the name of the most  liked video
# Out:
#                                title     likes
# 26143  BTS () 'Dynamite' Official MV  31837675

# %% [markdown]
# **least liked video**

# %%
#getting exact number of likes for least liked video
index.tail(1)
# Out:
#        likes
# 23855     22

# %%
name2 = df[df['likes']==22] #getting all features about the least liked video
name2
# INFERENCES :

#THe name of the least liked video is ""Leading the Charge | Circle K"". It has "22" likes.
# though the views are more, it seems people are not interested in the content of the video , hence the total number of likes
# is very less. THe number of dislikes for this video is also very less. 
# so we can say this video is neither liked nor disliked by large amount of people
# Out:
#           video_id                          title                channel_id  \
# 23855  cfP1eeNPT_E  Leading the Charge | Circle K  UC7kPuM7FmDnHjJHvJIPJP_Q
#
#       channel_title        published_at  view_count  likes  dislikes  \
# 23855      Circle K 2021-02-07 06:37:52     2254615     22         9
#
#        comment_count                                               tags  \
# 23855             12  Circle K EVs Electric Vehicles General Motors ...
#
#                                              description  \
# 23855  As stated by our fearless leader, were bringin...
#
#                                                 comments published_month
# 23855  This amazing seeing the future cleaner and mor...             Feb

# %%
name2[['title','likes']] #getting title of least liked video
# Out:
#                                title  likes
# 23855  Leading the Charge | Circle K     22

# %% [markdown]
# **12. Find the title of the video which has the maximum number of dislikes and the title of the video having
# minimum dislikes and write your inferences**

# %%
# sorting the data based on the number of dislikes in descending order 
dislike = df['dislikes'].sort_values(ascending=False).to_frame()
dislike
# Out:
#        dislikes
# 13591   2397733
# 26143   1814333
# 26894   1331181
# 7955    1259533
# 34758   1253187
# ...         ...
# 13454         7
# 14131         7
# 24546         6
# 33660         4
# 29482         3
#
# [37264 rows x 1 columns]

# %%
 dislike.head(1) # to get the exact number of dislikes for top most disliked video
# Out:
#        dislikes
# 13591   2397733

# %%
name3 = df[df['dislikes']==2397733] #getting all the features about the most disliked video
name3

#INFERENCES :

# The name of the video which has the maximum dislikes is ""Cuties | Official Trailer | Netflix""
# IT has ""2397733"" dislikes 
# The number of views is high for  this video which might be one of the main reasons for the number of dislikes
# This video is a trailer of a movie , hence we can say that the trailer cut didn't attract people much or didn't 
# grab the attention of people to watch the movie
# Out:
#           video_id                                title  \
# 13591  M0O7lLe4SmA  Cuties | Official Trailer | Netflix
#
#                      channel_id channel_title        published_at  view_count  \
# 13591  UCWOA1ZGywLbqmigxE4Qlvuw       Netflix 2020-08-18 14:00:00    17996395
#
#        likes  dislikes  comment_count  \
# 13591  94569   2397733         205009
#
#                                                     tags  \
# 13591  Cuties Mignonnes Netflix NetflixFilm Dance Mai...
#
#                                              description  \
# 13591  Eleven-year-old Amy starts to rebel against he...
#
#                                                 comments published_month
# 13591  I love how the mom is the bad guy for not lett...             Aug

# %%
name3[['title','dislikes']]   #retrieving the title of the most disliked video
# Out:
#                                      title  dislikes
# 13591  Cuties | Official Trailer | Netflix   2397733

# %% [markdown]
# **least disliked video**

# %%
dislike.tail(1) # to get the exact number of dislikes for the least disliked video
# Out:
#        dislikes
# 29482         3

# %%
name4 = df[df['dislikes']==3]  # getting all the features about  the least disliked video
name4[['title','dislikes']]   # retrieving the title of the least disliked video
# Out:
#                                         title  dislikes
# 29482  Tims For Good: A Taste Of The Familiar         3

# %%
name4

#INFERENCES

#the name of the least disliked video is ""Tims For Good: A Taste Of The Familiar""
# It has a total of "3" dislikes
# This  video has very less likes as well, hence we can say either the publishing channel isn't popular or the content of this 
# video wasn't good enough to get the attention of people
# Out:
#           video_id                                   title  \
# 29482  mFK01TbgDuo  Tims For Good: A Taste Of The Familiar
#
#                      channel_id channel_title        published_at  view_count  \
# 29482  UC_oe3z-MmiibqNtRvBKZQig   Tim Hortons 2021-01-26 21:39:04     1654486
#
#        likes  dislikes  comment_count                                  tags  \
# 29482     28         3             29  Tims For Good Tim Hortons healthcare
#
#                                              description  \
# 29482  The world has looked a little different, so we...
#
#                                                 comments published_month
# 29482  Man I love you Timmy's. Your the best coffee s...             Jan

# %% [markdown]
# **13. Does the number of views have any effect on how many people disliked the video? Support your
# answer with a metric and a plot.**

# %%
# using scatter plot to show the relationship between dislikes and view_count variables

df.plot(kind = 'scatter',x='view_count',y='dislikes',figsize=(20,5),s=40,fontsize=15) 

#figsize - for adjusting width and height of the plot
#size (s) - to increase the size of scatter plots
#fontsize - to adjust the size of fonts on x and y axis
# Out:
# <AxesSubplot:xlabel='view_count', ylabel='dislikes'>

# %%
# Getting the view counts and its respective dislikes in tabular format 

df[['dislikes','view_count']].sort_values(by='view_count',ascending=False)
# Out:
#        dislikes  view_count
# 26143   1814333  1322796924
# 7955    1259533  1269596718
# 18127    290062   976281963
# 16270    489286   915874131
# 34758   1253187   671712535
# ...         ...         ...
# 30972        32       23860
# 24537       116       23609
# 33004        31       21869
# 26366        15       20516
# 32368        33       20368
#
# [37264 rows x 2 columns]

# %% [markdown]
# **Inferences**
#
# From the above plot and table it is evident that the number of dislikes is directly influenced by the number of views
#
# For videos with more dislikes , the number of views is more
#
# For videos with less dislikes , the number of views is less
#
# In very few cases there is an exception as we can see in the scatter plot, where the dislikes are more even with very less view counts
#
# But in general we can conclude that number of dislikes is directly proportional to the number of views

# %% [markdown]
# **14. Display all the information about the videos that were published in January, and mention the count of
# videos that were published in January.**

# %% [markdown]
# 1. Count of Videos

# %%
#using value_counts to get total number of videos for every month 
counter = df['published_month'].value_counts().to_frame()  #number of videos published every month
counter
# Out:
#       published_month
# Oct              4976
# Sep              4854
# Nov              4821
# Aug              4250
# Dec              3063
# July             2331
# June             2305
# Mar              2248
# Feb              2125
# Apr              2119
# Jan              2099
# May              2073

# %%
counter.iloc[10].to_frame() #getting the count of number of videos released in the month of January by locating its index
#the total count is 2099
# Out:
#                   Jan
# published_month  2099

# %% [markdown]
# 2.All the information about the videos that were published in January

# %%
# Getting all the details about the videos published in the month of January

Jan_details = df[df['published_month']=='Jan']

Jan_details.sort_values('published_at')# sorting by date for the month of Jan

# displaying the details about all the videos released on the month of jan according to the date of publishment
#(2099 videos and its features)
# Out:
#           video_id                                              title  \
# 17036  RstF2eRsnT4                                      funny comment
# 14035  MpJIg_3DnLk  London's 2021 fireworks  Happy New Year Live! ...
# 36883  z2b0SDUmRoI                          ZARAMAY - FELICES FIESTAS
# 6196   9X6hH-Z1Tyw  David Guetta | United at Home - Paris Edition ...
# 1120   0y1Vsf1x4_Q  Defected Virtual Festival: We Dance As One 3.0...
# ...            ...                                                ...
# 21640  ZoaEsqhIjw8  DISGRACEFUL FOSSIL FOOTBALL, FINES SHOULD BE H...
# 25482  fZDKti9RQeg             Flight - Muggin (Official Music Video)
# 24166  dEIyS25XswQ  Bob The Drag Queen & Crystal Methyd | Purse Fi...
# 22636  aZDxGAtnrvE     Highlights FC Barcelona vs Athletic Club (2-1)
# 18449  ULqPKN1AIrA  FESTA DO VESTIARIO | PALMEIRAS BICAMPEO DA LIB...
#
#                      channel_id       channel_title        published_at  \
# ...
